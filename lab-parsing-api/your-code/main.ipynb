# %% [markdown]
# # Challenge: Rick and Morty API
#
# ![](http://as01.epimg.net/epik/imagenes/2019/02/12/portada/1549970850_227267_1549973816_noticia_normal.jpg)
#
#
# **In this challenge, you'll develop codes to parse and analyze data returned from the [Rick and Morty API](https://rickandmortyapi.com/).** The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
import requests
import json
import pandas as pd
import time

# %%
# your code here

url = 'https://rickandmortyapi.com/api/character/?page=1'
res = requests.get(url)
res_json = res.json()
characters = res_json['results']
for character in characters:
    name = character['name']
    print(name)
# Out:
# Rick Sanchez
# Morty Smith
# Summer Smith
# Beth Smith
# Jerry Smith
# Abadango Cluster Princess
# Abradolf Lincler
# Adjudicator Rick
# Agency Director
# Alan Rails
# Albert Einstein
# Alexander
# Alien Googah
# Alien Morty
# Alien Rick
# Amish Cyborg
# Annie
# Antenna Morty
# Antenna Rick
# Ants in my Eyes Johnson

# %%
flat_data = pd.json_normalize(characters)
flat_data.set_index('id', inplace=True)
flat_data.head()
# Out:
#             name status species type  gender  \
# id
# 1   Rick Sanchez  Alive   Human         Male
# 2    Morty Smith  Alive   Human         Male
# 3   Summer Smith  Alive   Human       Female
# 4     Beth Smith  Alive   Human       Female
# 5    Jerry Smith  Alive   Human         Male
#
#                                                 image  \
# id
# 1   https://rickandmortyapi.com/api/character/avat...
# 2   https://rickandmortyapi.com/api/character/avat...
# 3   https://rickandmortyapi.com/api/character/avat...
# 4   https://rickandmortyapi.com/api/character/avat...
# 5   https://rickandmortyapi.com/api/character/avat...
#
#                                               episode  \
# id
# 1   [https://rickandmortyapi.com/api/episode/1, ht...
# 2   [https://rickandmortyapi.com/api/episode/1, ht...
# 3   [https://rickandmortyapi.com/api/episode/6, ht...
# 4   [https://rickandmortyapi.com/api/episode/6, ht...
# 5   [https://rickandmortyapi.com/api/episode/6, ht...
#
#                                             url                   created  \
# id
# 1   https://rickandmortyapi.com/api/character/1  2017-11-04T18:48:46.250Z
# 2   https://rickandmortyapi.com/api/character/2  2017-11-04T18:50:21.651Z
# 3   https://rickandmortyapi.com/api/character/3  2017-11-04T19:09:56.428Z
# 4   https://rickandmortyapi.com/api/character/4  2017-11-04T19:22:43.665Z
# 5   https://rickandmortyapi.com/api/character/5  2017-11-04T19:26:56.301Z
#
#                       origin.name  \
# id
# 1                   Earth (C-137)
# 2                         unknown
# 3   Earth (Replacement Dimension)
# 4   Earth (Replacement Dimension)
# 5   Earth (Replacement Dimension)
#
#                                      origin.url  \
# id
# 1    https://rickandmortyapi.com/api/location/1
# 2
# 3   https://rickandmortyapi.com/api/location/20
# 4   https://rickandmortyapi.com/api/location/20
# 5   https://rickandmortyapi.com/api/location/20
#
#                     location.name                                 location.url
# id
# 1                Citadel of Ricks   https://rickandmortyapi.com/api/location/3
# 2                Citadel of Ricks   https://rickandmortyapi.com/api/location/3
# 3   Earth (Replacement Dimension)  https://rickandmortyapi.com/api/location/20
# 4   Earth (Replacement Dimension)  https://rickandmortyapi.com/api/location/20
# 5   Earth (Replacement Dimension)  https://rickandmortyapi.com/api/location/20

# %%
flat_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 1 to 20
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           20 non-null     object
#  1   status         20 non-null     object
#  2   species        20 non-null     object
#  3   type           20 non-null     object
#  4   gender         20 non-null     object
#  5   image          20 non-null     object
#  6   episode        20 non-null     object
#  7   url            20 non-null     object
#  8   created        20 non-null     object
#  9   origin.name    20 non-null     object
#  10  origin.url     20 non-null     object
#  11  location.name  20 non-null     object
#  12  location.url   20 non-null     object
# dtypes: object(13)
# memory usage: 2.2+ KB

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
url_pattern = 'https://rickandmortyapi.com/api/character/?page=%s'

df= pd.DataFrame()

for page in range(1, 20):

    url = url_pattern % page
    time.sleep(1)
    res = requests.get(url)
    res_json = res.json()
    personajes = res_json['results']

    flat_data = pd.json_normalize(personajes)
    flat_data = flat_data.set_index('id')
    df = df.append(flat_data)

# %%
df.head()
# Out:
#             name status species type  gender  \
# id
# 1   Rick Sanchez  Alive   Human         Male
# 2    Morty Smith  Alive   Human         Male
# 3   Summer Smith  Alive   Human       Female
# 4     Beth Smith  Alive   Human       Female
# 5    Jerry Smith  Alive   Human         Male
#
#                                                 image  \
# id
# 1   https://rickandmortyapi.com/api/character/avat...
# 2   https://rickandmortyapi.com/api/character/avat...
# 3   https://rickandmortyapi.com/api/character/avat...
# 4   https://rickandmortyapi.com/api/character/avat...
# 5   https://rickandmortyapi.com/api/character/avat...
#
#                                               episode  \
# id
# 1   [https://rickandmortyapi.com/api/episode/1, ht...
# 2   [https://rickandmortyapi.com/api/episode/1, ht...
# 3   [https://rickandmortyapi.com/api/episode/6, ht...
# 4   [https://rickandmortyapi.com/api/episode/6, ht...
# 5   [https://rickandmortyapi.com/api/episode/6, ht...
#
#                                             url                   created  \
# id
# 1   https://rickandmortyapi.com/api/character/1  2017-11-04T18:48:46.250Z
# 2   https://rickandmortyapi.com/api/character/2  2017-11-04T18:50:21.651Z
# 3   https://rickandmortyapi.com/api/character/3  2017-11-04T19:09:56.428Z
# 4   https://rickandmortyapi.com/api/character/4  2017-11-04T19:22:43.665Z
# 5   https://rickandmortyapi.com/api/character/5  2017-11-04T19:26:56.301Z
#
#                       origin.name  \
# id
# 1                   Earth (C-137)
# 2                         unknown
# 3   Earth (Replacement Dimension)
# 4   Earth (Replacement Dimension)
# 5   Earth (Replacement Dimension)
#
#                                      origin.url  \
# id
# 1    https://rickandmortyapi.com/api/location/1
# 2
# 3   https://rickandmortyapi.com/api/location/20
# 4   https://rickandmortyapi.com/api/location/20
# 5   https://rickandmortyapi.com/api/location/20
#
#                     location.name                                 location.url
# id
# 1                Citadel of Ricks   https://rickandmortyapi.com/api/location/3
# 2                Citadel of Ricks   https://rickandmortyapi.com/api/location/3
# 3   Earth (Replacement Dimension)  https://rickandmortyapi.com/api/location/20
# 4   Earth (Replacement Dimension)  https://rickandmortyapi.com/api/location/20
# 5   Earth (Replacement Dimension)  https://rickandmortyapi.com/api/location/20

# %%
df.tail()
# Out:
#                     name   status   species           type   gender  \
# id
# 376  Veronica Ann Bennet    Alive     Alien      Gazorpian   Female
# 377          Voltematron     Dead     Alien       Parasite  unknown
# 378   Wall Crawling Rick  unknown  Humanoid  Lizard-Person     Male
# 379    Wedding Bartender  unknown     Alien                    Male
# 380         Unknown Rick  unknown     Human                    Male
#
#                                                  image  \
# id
# 376  https://rickandmortyapi.com/api/character/avat...
# 377  https://rickandmortyapi.com/api/character/avat...
# 378  https://rickandmortyapi.com/api/character/avat...
# 379  https://rickandmortyapi.com/api/character/avat...
# 380  https://rickandmortyapi.com/api/character/avat...
#
#                                                episode  \
# id
# 376        [https://rickandmortyapi.com/api/episode/7]
# 377       [https://rickandmortyapi.com/api/episode/29]
# 378       [https://rickandmortyapi.com/api/episode/22]
# 379       [https://rickandmortyapi.com/api/episode/21]
# 380  [https://rickandmortyapi.com/api/episode/22, h...
#
#                                                url                   created  \
# id
# 376  https://rickandmortyapi.com/api/character/376  2018-01-10T19:27:06.246Z
# 377  https://rickandmortyapi.com/api/character/377  2018-01-10T19:29:08.116Z
# 378  https://rickandmortyapi.com/api/character/378  2018-01-10T19:33:30.804Z
# 379  https://rickandmortyapi.com/api/character/379  2018-01-10T19:37:41.375Z
# 380  https://rickandmortyapi.com/api/character/380  2018-01-10T19:44:22.262Z
#
#      origin.name                                   origin.url  \
# id
# 376  Gazorpazorp  https://rickandmortyapi.com/api/location/40
# 377      unknown
# 378      unknown
# 379      unknown
# 380      unknown
#
#                      location.name  \
# id
# 376                    Gazorpazorp
# 377  Earth (Replacement Dimension)
# 378               Citadel of Ricks
# 379                 Planet Squanch
# 380                        unknown
#
#                                     location.url
# id
# 376  https://rickandmortyapi.com/api/location/40
# 377  https://rickandmortyapi.com/api/location/20
# 378   https://rickandmortyapi.com/api/location/3
# 379  https://rickandmortyapi.com/api/location/35
# 380

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The character who appeared in most episodes (aside from Rick and Morty, of course!).
#
# * The total number of dead characters.
#
# * A list of all character origins (without duplicates).

# %%
secondary_chars = df[(df['name'] != 'Morty Smith') & (df['name'] != 'Rick Sanchez')]
cant_episodes = [len(char) for char in secondary_chars.episode]
secondary_chars['cant_episodes'] = cant_episodes
secondary_chars.sort_values('cant_episodes', ascending=False).head(1)
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_1288/2006728873.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   secondary_chars['cant_episodes'] = cant_episodes
#             name status species type  gender  \
# id
# 3   Summer Smith  Alive   Human       Female
#
#                                                 image  \
# id
# 3   https://rickandmortyapi.com/api/character/avat...
#
#                                               episode  \
# id
# 3   [https://rickandmortyapi.com/api/episode/6, ht...
#
#                                             url                   created  \
# id
# 3   https://rickandmortyapi.com/api/character/3  2017-11-04T19:09:56.428Z
#
#                       origin.name  \
# id
# 3   Earth (Replacement Dimension)
#
#                                      origin.url  \
# id
# 3   https://rickandmortyapi.com/api/location/20
#
#                     location.name  \
# id
# 3   Earth (Replacement Dimension)
#
#                                    location.url  cant_episodes
# id
# 3   https://rickandmortyapi.com/api/location/20             42

# %%
# df[df['status'] == 'Dead']
df.groupby("status").agg({"status":"count"})
# Out:
#          status
# status
# Alive       197
# Dead        129
# unknown      54

# %%
df.groupby("origin.name").agg({"origin.name":"count"})
# Out:
#                                             origin.name
# origin.name
# Abadango                                              1
# Alphabetrium                                          4
# Anatomy Park                                          6
# Bepis 9                                               1
# Bird World                                            1
# Cronenberg Earth                                      2
# Detoxifier                                            2
# Earth (5-126)                                         1
# Earth (C-137)                                        31
# Earth (C-500A)                                        6
# Earth (D-99)                                          1
# Earth (D716)                                          1
# Earth (D716-B)                                        1
# Earth (D716-C)                                        1
# Earth (Evil Rick's Target Dimension)                  5
# Earth (Giant Telepathic Spiders Dimension)            2
# Earth (J-22)                                          1
# Earth (J19ζ7)                                         1
# Earth (K-22)                                          2
# Earth (K-83)                                          1
# Earth (Replacement Dimension)                        52
# Eric Stoltz Mask Earth                                1
# Fantasy World                                         4
# Gazorpazorp                                           6
# Gear World                                            1
# Giant's Town                                          1
# Glaagablaaga                                          1
# Gromflom Prime                                        1
# Hamster in Butt World                                 1
# Hideout Planet                                        1
# Krootabulon                                           2
# Kyle's Teenyverse                                     1
# Larva Alien's Planet                                  1
# Mega Gargantuan Kingdom                               1
# Mr. Goldenfold's dream                                4
# Mr. Meeseeks Box                                      1
# Nuptia 4                                              6
# Planet Squanch                                        1
# Plopstar                                              1
# Pluto                                                 2
# Post-Apocalyptic Earth                               10
# Purge Planet                                          4
# Resort Planet                                         5
# Rick's Battery Microverse                             1
# Roy: A Life Well Lived                                1
# Signus 5 Expanse                                      1
# The Menagerie                                         1
# Trunk World                                           2
# Unity's Planet                                        5
# Venzenulon 7                                          1
# Zeep Xanflorp's Miniverse                             2
# unknown                                             187
