# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
import feedparser

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
radar_atom = feedparser.parse(url)
# radar_atom

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
keys = list(radar_atom.keys())
keys
# Out:
# ['feed',
#  'entries',
#  'bozo',
#  'headers',
#  'etag',
#  'updated',
#  'updated_parsed',
#  'href',
#  'status',
#  'encoding',
#  'version',
#  'namespaces']

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
keys_feed = list(radar_atom['feed'].keys())
keys_feed
# Out:
# ['title',
#  'title_detail',
#  'links',
#  'link',
#  'subtitle',
#  'subtitle_detail',
#  'updated',
#  'updated_parsed',
#  'language',
#  'sy_updateperiod',
#  'sy_updatefrequency',
#  'generator_detail',
#  'generator',
#  'feedburner_info',
#  'geo_lat',
#  'geo_long',
#  'feedburner_emailserviceid',
#  'feedburner_feedburnerhostname']

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
cols = ['title','subtitle','author','link']
values_feed = dict()

for col in cols:
    values_feed[col] = radar_atom['feed'].get(col)
    print(col,':', values_feed[col])
    
# values_feed
# Out:
# title : Radar
# subtitle : Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology
# author : None
# link : https://www.oreilly.com/radar

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
len(radar_atom['entries'])
# Out:
# 60

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
list(radar_atom['entries'][0].keys())
# Out:
# ['title',
#  'title_detail',
#  'links',
#  'link',
#  'comments',
#  'published',
#  'published_parsed',
#  'authors',
#  'author',
#  'author_detail',
#  'tags',
#  'id',
#  'guidislink',
#  'summary',
#  'summary_detail',
#  'content',
#  'wfw_commentrss',
#  'slash_comments']

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
titles = [radar_atom.entries[i].title for i in range(len(radar_atom.entries))]
titles[:10]
# Out:
# ['The Cloud in 2021: Adoption Continues',
#  'Radar trends to watch: December 2021',
#  'Low-Code and the Democratization of Programming',
#  'Remote Teams in ML/AI',
#  'Radar trends to watch: November 2021',
#  'The Sobering Truth About the Impact of Your Business Ideas',
#  'MLOps and DevOps: Why Data Makes It Different',
#  'The Quality of Auto-Generated Code',
#  'Radar trends to watch: October 2021',
#  'Ethical Social Media: Oxymoron or Attainable Goal?']

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
shorttitles = [radar_atom.entries[i].title for i in range(len(radar_atom.entries)) if 'Four short links' in radar_atom.entries[i].title]
percent = round(( len(shorttitles) / len(titles) ) * 100, 1)
print(f'The percentage of "Four short links" is:{percent}%')
# Out:
# The percentage of "Four short links" is:18.3%

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd
df=pd.DataFrame(radar_atom['entries'])
df.head()
# Out:
#                                              title  \
# 0            The Cloud in 2021: Adoption Continues
# 1             Radar trends to watch: December 2021
# 2  Low-Code and the Democratization of Programming
# 3                            Remote Teams in ML/AI
# 4             Radar trends to watch: November 2021
#
#                                         title_detail  \
# 0  {'type': 'text/plain', 'language': None, 'base...
# 1  {'type': 'text/plain', 'language': None, 'base...
# 2  {'type': 'text/plain', 'language': None, 'base...
# 3  {'type': 'text/plain', 'language': None, 'base...
# 4  {'type': 'text/plain', 'language': None, 'base...
#
#                                                links  \
# 0  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 1  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 2  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 3  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 4  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                                                 link  \
# 0  https://www.oreilly.com/radar/the-cloud-in-202...
# 1  https://www.oreilly.com/radar/radar-trends-to-...
# 2  https://www.oreilly.com/radar/low-code-and-the...
# 3  https://www.oreilly.com/radar/remote-teams-in-...
# 4  https://www.oreilly.com/radar/radar-trends-to-...
#
#                                             comments  \
# 0  https://www.oreilly.com/radar/the-cloud-in-202...
# 1  https://www.oreilly.com/radar/radar-trends-to-...
# 2  https://www.oreilly.com/radar/low-code-and-the...
# 3  https://www.oreilly.com/radar/remote-teams-in-...
# 4  https://www.oreilly.com/radar/radar-trends-to-...
#
#                          published                       published_parsed  \
# 0  Tue, 07 Dec 2021 12:26:55 +0000   (2021, 12, 7, 12, 26, 55, 1, 341, 0)
# 1  Wed, 01 Dec 2021 13:48:10 +0000   (2021, 12, 1, 13, 48, 10, 2, 335, 0)
# 2  Tue, 16 Nov 2021 12:36:18 +0000  (2021, 11, 16, 12, 36, 18, 1, 320, 0)
# 3  Tue, 09 Nov 2021 14:05:48 +0000    (2021, 11, 9, 14, 5, 48, 1, 313, 0)
# 4  Tue, 02 Nov 2021 11:40:17 +0000   (2021, 11, 2, 11, 40, 17, 1, 306, 0)
#
#                        authors         author              author_detail  \
# 0  [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 1  [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 2                         [{}]                                       NaN
# 3     [{'name': 'Q McCallum'}]     Q McCallum     {'name': 'Q McCallum'}
# 4  [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
#
#                                                 tags  \
# 0  [{'term': 'Cloud', 'scheme': None, 'label': No...
# 1  [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 2  [{'term': 'Programming', 'scheme': None, 'labe...
# 3  [{'term': 'Building a data culture', 'scheme':...
# 4  [{'term': 'Radar Trends', 'scheme': None, 'lab...
#
#                                        id  guidislink  \
# 0  https://www.oreilly.com/radar/?p=14129       False
# 1  https://www.oreilly.com/radar/?p=14103       False
# 2  https://www.oreilly.com/radar/?p=14083       False
# 3  https://www.oreilly.com/radar/?p=14075       False
# 4  https://www.oreilly.com/radar/?p=14066       False
#
#                                              summary  \
# 0  Last year, our report on cloud adoption showed...
# 1  The last month had a few surprises. Three item...
# 2  In the past decade, the growth in low-code and...
# 3  I&#8217;m well-versed in the ups and downs of ...
# 4  While October’s news was dominated by Facebook...
#
#                                       summary_detail  \
# 0  {'type': 'text/html', 'language': None, 'base'...
# 1  {'type': 'text/html', 'language': None, 'base'...
# 2  {'type': 'text/html', 'language': None, 'base'...
# 3  {'type': 'text/html', 'language': None, 'base'...
# 4  {'type': 'text/html', 'language': None, 'base'...
#
#                                              content  \
# 0  [{'type': 'text/html', 'language': None, 'base...
# 1  [{'type': 'text/html', 'language': None, 'base...
# 2  [{'type': 'text/html', 'language': None, 'base...
# 3  [{'type': 'text/html', 'language': None, 'base...
# 4  [{'type': 'text/html', 'language': None, 'base...
#
#                                       wfw_commentrss slash_comments
# 0  https://www.oreilly.com/radar/the-cloud-in-202...              0
# 1  https://www.oreilly.com/radar/radar-trends-to-...              0
# 2  https://www.oreilly.com/radar/low-code-and-the...              0
# 3  https://www.oreilly.com/radar/remote-teams-in-...              0
# 4  https://www.oreilly.com/radar/radar-trends-to-...              0

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
authors = df.groupby('author', as_index=False).agg({'title':'count'}).sort_values('title', ascending=False)
authors.columns = ['author', 'entries']
authors
# Out:
#                                          author  entries
# 6                                 Mike Loukides       28
# 8                                Nat Torkington       11
# 0                                                      4
# 1                                  Chris Butler        3
# 13                                 Tim O’Reilly        3
# 11                                   Q McCallum        2
# 2   Eric Colson, Daragh Sibley and Dave Spiegel        1
# 3                           Hugo Bowne-Anderson        1
# 4                                 Kevlin Henney        1
# 5                                   Mike Barlow        1
# 7               Mike Loukides and Kevlin Henney        1
# 9                               Nitesh Dhanjani        1
# 10              Patrick Hall and Ayoub Ouederni        1
# 12       Shayan Mohanty and Hugo Bowne-Anderson        1
# 14         Ville Tuulos and Hugo Bowne-Anderson        1

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
df['title_length'] = df['title'].apply(len)
df[['author', 'title', 'title_length']].sort_values('title_length', ascending=False)
# Out:
#                                          author  \
# 40                                Mike Loukides
# 24                              Nitesh Dhanjani
# 5   Eric Colson, Daragh Sibley and Dave Spiegel
# 37
# 46
# 14                                Mike Loukides
# 9                                   Mike Barlow
# 2
# 6          Ville Tuulos and Hugo Bowne-Anderson
# 36
# 41              Patrick Hall and Ayoub Ouederni
# 32                                 Tim O’Reilly
# 0                                 Mike Loukides
# 13                                 Chris Butler
# 11                                Mike Loukides
# 50                                Mike Loukides
# 39                                Mike Loukides
# 4                                 Mike Loukides
# 1                                 Mike Loukides
# 43                                Mike Loukides
# 8                                 Mike Loukides
# 28                                Mike Loukides
# 15                                Mike Loukides
# 16                                 Chris Butler
# 7               Mike Loukides and Kevlin Henney
# 58                               Nat Torkington
# 34                                Mike Loukides
# 30                                Mike Loukides
# 20                                 Tim O’Reilly
# 23                                Mike Loukides
# 19       Shayan Mohanty and Hugo Bowne-Anderson
# 18                                Mike Loukides
# 26                                Mike Loukides
# 54                                Kevlin Henney
# 47                                Mike Loukides
# 44                               Nat Torkington
# 56                               Nat Torkington
# 55                               Nat Torkington
# 53                               Nat Torkington
# 52                               Nat Torkington
# 51                               Nat Torkington
# 45                               Nat Torkington
# 49                               Nat Torkington
# 48                               Nat Torkington
# 59                               Nat Torkington
# 31                          Hugo Bowne-Anderson
# 10                                Mike Loukides
# 27                                 Tim O’Reilly
# 35                                Mike Loukides
# 33                                Mike Loukides
# 29                                Mike Loukides
# 57                                Mike Loukides
# 22                                Mike Loukides
# 3                                    Q McCallum
# 17                                Mike Loukides
# 38                                Mike Loukides
# 21                                 Chris Butler
# 12                                   Q McCallum
# 25                                Mike Loukides
# 42                                Mike Loukides
#
#                                                 title  title_length
# 40  Where Programming, Ops, AI, and the Cloud are ...            60
# 24  AI Powered Misinformation and Manipulation at ...            58
# 5   The Sobering Truth About the Impact of Your Bu...            58
# 37  5 infrastructure and operations trends to watc...            55
# 46  O’Reilly’s top 20 live online training courses...            54
# 14  Defending against ransomware is all about the ...            52
# 9   Ethical Social Media: Oxymoron or Attainable G...            50
# 2     Low-Code and the Democratization of Programming            47
# 6       MLOps and DevOps: Why Data Makes It Different            45
# 36         5 things on our data and AI radar for 2021            42
# 41          Seven Legal Questions for Data Scientists            41
# 32           The End of Silicon Valley as We Know It?            40
# 0               The Cloud in 2021: Adoption Continues            37
# 13              A Way Forward with Communal Computing            37
# 11              Radar trends to watch: September 2021            37
# 50               Radar trends to watch: December 2020            36
# 39               Radar trends to watch: February 2021            36
# 4                Radar trends to watch: November 2021            36
# 1                Radar trends to watch: December 2021            36
# 43                Radar trends to watch: January 2021            35
# 8                 Radar trends to watch: October 2021            35
# 28                 AI Adoption in the Enterprise 2021            34
# 15                 Radar trends to watch: August 2021            34
# 16                 Communal Computing’s Many Problems            34
# 7                  The Quality of Auto-Generated Code            34
# 58                 Four short links: 10 November 2020            34
# 34                  Radar trends to watch: March 2021            33
# 30                  Radar trends to watch: April 2021            33
# 20                  Two economies. Two sets of rules.            33
# 23                   Radar trends to watch: June 2021            32
# 19                   Hand Labeling Considered Harmful            32
# 18                   Radar trends to watch: July 2021            32
# 26                    Radar trends to watch: May 2021            31
# 54                    On Exactitude in Technical Debt            31
# 47                    What is functional programming?            31
# 44                      Four short links: 14 Dec 2020            29
# 56                      Four short links: 13 Nov 2020            29
# 55                      Four short links: 17 Nov 2020            29
# 53                      Four short links: 20 Nov 2020            29
# 52                      Four short links: 24 Nov 2020            29
# 51                      Four short links: 27 Nov 2020            29
# 45                       Four short links: 8 Dec 2020            28
# 49                       Four short links: 1 Dec 2020            28
# 48                       Four short links: 4 Dec 2020            28
# 59                       Four short links: 6 Nov 2020            28
# 31                        InfoTribes, Reality Brokers            27
# 10                         2021 Data/AI Salary Survey            26
# 27                         Checking Jeff Bezos’s Math            26
# 35                          Product Management for AI            25
# 33                          The Next Generation of AI            25
# 29                           NFTs: Owning Digital Art            24
# 57                           Multi-Paradigm Languages            24
# 22                             Code as Infrastructure            22
# 3                               Remote Teams in ML/AI            21
# 17                                Thinking About Glue            19
# 38                                 The Wrong Question            18
# 21                                 Communal Computing            18
# 12                                    Rebranding Data            15
# 25                                     DeepCheapFakes            14
# 42                                           Patterns             8

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
ML_titles = [radar_atom.entries[i].title for i in range(len(radar_atom.entries)) if "machine learning" in radar_atom.entries[i].summary.lower()]
ML_titles
# Out:
# ['MLOps and DevOps: Why Data Makes It Different',
#  'Rebranding Data',
#  'Hand Labeling Considered Harmful',
#  'AI Powered Misinformation and Manipulation at Scale #GPT-3',
#  'Radar trends to watch: April 2021',
#  '5 things on our data and AI radar for 2021',
#  'Seven Legal Questions for Data Scientists']
